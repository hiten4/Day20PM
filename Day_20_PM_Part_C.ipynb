# %% [markdown]
# <a href="https://colab.research.google.com/github/hiten4/Day20PM/blob/main/Day_20_PM_Part_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Q1 — Difference between normal distribution and standard normal distribution
#
# A normal distribution is any Gaussian distribution defined by its mean (μ) and standard deviation (σ). It can have different centers and spreads.
#
# A standard normal distribution is a special case of normal distribution where:
#
# * Mean (μ) = 0
# * Standard deviation (σ) = 1
#
# Key difference:
#
# * Normal → general form (any μ, σ)
# * Standard Normal → normalized form (μ = 0, σ = 1)
#
# ---

# %% [markdown]
# ### Q2 — Z-score function

# %%
def z_score(x, mean, std):
    return (x - mean) / std


# Example usage
data = [10, 20, 30, 40, 50]

mean_val = sum(data) / len(data)

variance = sum((x - mean_val) ** 2 for x in data) / len(data)
std_val = variance ** 0.5

z_values = [z_score(x, mean_val, std_val) for x in data]

print(z_values)
# Out:
# [-1.414213562373095, -0.7071067811865475, 0.0, 0.7071067811865475, 1.414213562373095]

# %% [markdown]
# ---
#
# ### Q3 — Hypothesis testing explanation
#
# Hypothesis testing is a statistical method used to make decisions based on data.
#
# * Null hypothesis (H₀): Assumes no effect or no difference
# * Alternative hypothesis (H₁): Assumes there is an effect or difference
#
# The p-value measures how likely the observed result is if H₀ is true.
#
# The significance level (α) is a threshold (commonly 0.05).
# If p-value < α → reject H₀
# If p-value ≥ α → fail to reject H₀
#
# ---
